# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1596 entries, 0 to 1595
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1596 non-null   float64
#  1   volatile acidity      1596 non-null   float64
#  2   citric acid           1596 non-null   float64
#  3   residual sugar        1596 non-null   float64
#  4   chlorides             1596 non-null   float64
#  5   free sulfur dioxide   1596 non-null   float64
#  6   total sulfur dioxide  1596 non-null   float64
#  7   density               1596 non-null   float64
#  8   pH                    1596 non-null   float64
#  9   sulphates             1596 non-null   float64
#  10  alcohol               1596 non-null   float64
#  11  quality               1596 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 149.8 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1596.000000       1596.000000  1596.000000     1596.000000
# mean        8.314160          0.527954     0.270276        2.535558
# std         1.732203          0.179176     0.193894        1.405515
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.600000          1.580000     0.790000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1596.000000          1596.000000           1596.000000  1596.000000
# mean      0.087120            15.858396             46.382206     0.996744
# std       0.045251            10.460554             32.839138     0.001888
# ...

# %%
df.shape
# Out:
# (1596, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# For duplicate 
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1591    False
# 1592    False
# 1593     True
# 1594    False
# 1595    False
# Length: 1596, dtype: bool

# %%
# For duplicate 
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1560            7.2             0.695         0.13            2.00      0.076
# 1561            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1578            6.2             0.560         0.09            1.70      0.053
# 1593            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
# Remove the duplicates 

df.drop_duplicates(inplace = True)

# %%
# For duplicate 
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 1590    False
# 1591    False
# 1592    False
# 1594    False
# 1595    False
# Length: 1357, dtype: bool

# %%
df.shape
# Out:
# (1357, 12)

# %%
# Correlation find
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.254021     0.668911
# volatile acidity          -0.254021          1.000000    -0.553560
# citric acid                0.668911         -0.553560     1.000000
# residual sugar             0.100159          0.000088     0.138478
# chlorides                  0.085543          0.058134     0.190153
# free sulfur dioxide       -0.144223         -0.020513    -0.053468
# total sulfur dioxide      -0.107164          0.072269     0.044813
# density                    0.673540          0.024359     0.355693
# pH                        -0.687920          0.247245    -0.544342
# sulphates                  0.189638         -0.262149     0.312295
# alcohol                   -0.075568         -0.196397     0.103192
# quality                    0.123293         -0.396584     0.236467
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.quality.value_counts()
# Conclusion :- So, it is a imbalance dataset
# Out:
# quality
# 5    576
# 6    535
# 7    167
# 4     52
# 8     17
# 3     10
# Name: count, dtype: int64

# %%
df.quality.value_counts().plot(kind='bar')
# Conclusion :- So, it is a imbalance dataset
plt.xlabel('Wind Quality...')
plt.ylabel('Count..')
# Out:
# Text(0, 0.5, 'Count..')

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#Cheak all distribution using visulization
for column in df.columns:
    sns.histplot(df[column], kde=True)

# %%
#Cheak all distribution using visulization per content
sns.histplot(df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
#ulivariate, multivariate, bivarite analysis
sns.pairplot(df)

# %%
#catagorical plot
sns.catplot(x = 'quality', y = 'alcohol', data = df, kind = 'box')

# %%
sns.scatterplot(x= 'alcohol', y = 'pH', hue = 'quality', data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
