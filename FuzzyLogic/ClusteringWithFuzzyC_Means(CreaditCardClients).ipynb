# %% [markdown]
# # ***4.1.30***

# %%
# !pip install scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.12/dist-packages (0.5.0)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import skfuzzy as fuzz

# %%
dataset = pd.read_csv('/content/credit_card_clients.csv', header = 1)

# %%
dataset.head(3)
# Out:
#    ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0   1      20000    2  ...         0         0                           1
# 1   2     120000    2  ...         0      2000                           1
# 2   3      90000    2  ...      1000      5000                           0
#
# [3 rows x 25 columns]

# %%
dataset.shape
# Out:
# (30000, 25)

# %%
dataset.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
dataset['BILL TOTAL'] = dataset['BILL_AMT1'] + dataset['BILL_AMT2'] + dataset['BILL_AMT3'] + dataset['BILL_AMT4'] + dataset['BILL_AMT5'] + dataset['BILL_AMT6']

# %%
dataset.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'BILL TOTAL'],
#       dtype='object')

# %%
features = ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
       'default payment next month', 'BILL TOTAL']

# %%
dataset.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month  BILL TOTAL
# 0   1      20000    2  ...         0                           1        7704
# 1   2     120000    2  ...      2000                           1       17077
# 2   3      90000    2  ...      5000                           0      101653
# 3   4      50000    2  ...      1000                           0      231334
# 4   5      50000    1  ...       679                           0      109339
# 5   6      50000    1  ...       800                           0      238114
# 6   7     500000    1  ...     13770                           0     2724595
# 7   8     100000    2  ...      1542                           0       13486
# 8   9     140000    2  ...      1000                           0       65212
# 9  10      20000    1  ...         0                           0       26919
#
# [10 rows x 26 columns]

# %%
dataset.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# BILL TOTAL                    0
# dtype: int64

# %%
dataset['LIMIT_BAL'].mean()
# Out:
# np.float64(167484.32266666667)

# %%
dataset['BILL TOTAL'].mean()
# Out:
# np.float64(269861.6712)

# %% [markdown]
# # ***4.2.31***

# %% [markdown]
# ### ***Using CT Start.....***

# %%
df = dataset

# %%
df.head(3)
# Out:
#    ID  LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month  BILL TOTAL
# 0   1      20000    2  ...         0                           1        7704
# 1   2     120000    2  ...      2000                           1       17077
# 2   3      90000    2  ...      5000                           0      101653
#
# [3 rows x 26 columns]

# %%
dataset.head(3)
# Out:
#    ID  LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month  BILL TOTAL
# 0   1      20000    2  ...         0                           1        7704
# 1   2     120000    2  ...      2000                           1       17077
# 2   3      90000    2  ...      5000                           0      101653
#
# [3 rows x 26 columns]

# %%
df = df.drop(columns=['ID'])

# %%
# --- Separate features (you can also drop target column if needed) ---
# For unsupervised clustering, we typically drop the target label
if 'default payment next month' in df.columns:
    df_features = df.drop(columns=['default payment next month'])
else:
    df_features = df.copy()

# %%
# --- Standardize the data (important for FCM) ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_features)

# %%
# --- Transpose for scikit-fuzzy (expects features x samples) ---
X_scaled = X_scaled.T

# %%
# --- Choose number of clusters ---
n_clusters = 3  # You can experiment with 2–6 clusters

# %%
# --- Run Fuzzy C-Means ---
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    X_scaled, c=n_clusters, m=2, error=0.005, maxiter=1000, init=None
)

# %%
# --- Predict cluster membership for each sample ---
cluster_membership = np.argmax(u, axis=0)

# %%
# --- Add cluster labels to original DataFrame ---
df['Cluster'] = cluster_membership

# %%
# --- Show cluster distribution ---
print(df['Cluster'].value_counts())
# Out:
# Cluster
# 1    11231
# 0    11000
# 2     7769
# Name: count, dtype: int64

# %%
# --- Visualize 2D projection (using two features for simplicity) ---
plt.figure(figsize=(8, 6))
plt.scatter(df_features.iloc[:, 0], df_features.iloc[:, 1], c=cluster_membership, cmap='viridis', s=30)
plt.title('Fuzzy C-Means Clustering (2D projection)')
plt.xlabel(df_features.columns[0])
plt.ylabel(df_features.columns[1])
plt.colorbar(label='Cluster')
plt.show()

# %%
# --- Print Fuzzy Partition Coefficient (FPC) ---
print(f"Fuzzy Partition Coefficient (FPC): {fpc:.4f}")
# Out:
# Fuzzy Partition Coefficient (FPC): 0.3638

# %% [markdown]
# ### ***Using CT End.....***

# %% [markdown]
# ### ***From Video Start...***

# %% [markdown]
# ***Preprocessing the data.....***

# %%
x = dataset.iloc[:, [1, 25]].values

# %%
x
# Out:
# array([[ 20000,   7704],
#        [120000,  17077],
#        [ 90000, 101653],
#        ...,
#        [ 30000,  70496],
#        [ 80000, 266611],
#        [ 50000, 230874]])

# %%
x.min(), x.max()
# Out:
# (np.int64(-336259), np.int64(5263883))

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x.min(), x.max()
# Out:
# (np.float64(0.0), np.float64(1.0))

# %%
x
# Out:
# array([[0.01010101, 0.06142041],
#        [0.11111111, 0.06309411],
#        [0.08080808, 0.07819659],
#        ...,
#        [0.02020202, 0.07263298],
#        [0.07070707, 0.10765263],
#        [0.04040404, 0.10127118]])

# %%
x = x.T

# %% [markdown]
# ***Number of cluster defined......***

# %%
n_clusters = 3

# %%
# --- Run Fuzzy C-Means ---
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    x, c=n_clusters, m=2, error=0.005, maxiter=1000, init=None
)

# %%
# --- Predict cluster membership for each sample ---
cluster_membership = np.argmax(u, axis=0)

# %%
cluster_membership
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# --- Add cluster labels to original DataFrame ---
dataset['Cluster'] = cluster_membership

# %%
print("Cluster Counts:\n", dataset['Cluster'].value_counts())
# Out:
# Cluster Counts:
#  Cluster
# 0    14262
# 2    10964
# 1     4774
# Name: count, dtype: int64

# %%
dataset.head(20)
# Out:
#     ID  LIMIT_BAL  SEX  ...  default payment next month  BILL TOTAL  Cluster
# 0    1      20000    2  ...                           1        7704        0
# 1    2     120000    2  ...                           1       17077        0
# 2    3      90000    2  ...                           0      101653        0
# 3    4      50000    2  ...                           0      231334        0
# 4    5      50000    1  ...                           0      109339        0
# 5    6      50000    1  ...                           0      238114        0
# 6    7     500000    1  ...                           0     2724595        1
# 7    8     100000    2  ...                           0       13486        0
# 8    9     140000    2  ...                           0       65212        2
# 9   10      20000    1  ...                           0       26919        0
# 10  11     200000    2  ...                           0       34467        2
# 11  12     260000    2  ...                           0       88369        2
# 12  13     630000    2  ...                           0       41007        1
# 13  14      70000    1  ...                           1      338685        0
# 14  15     250000    1  ...                           0      373591        2
# 15  16      50000    2  ...                           0      196416        0
# 16  17      20000    1  ...                           1      106161        0
# 17  18     320000    1  ...                           0      966014        1
# 18  19     360000    2  ...                           0           0        1
# 19  20     180000    2  ...                           0           0        2
#
# [20 rows x 27 columns]

# %%
print(f"Fuzzy Partition Coefficient (FPC): {fpc:.4f}")
# Out:
# Fuzzy Partition Coefficient (FPC): 0.7255

# %%
# Use original scaled but NOT transposed data for plotting
X_plot = X_scaled.T  # shape = (n_samples, n_features)


plt.figure(figsize=(8,6))
plt.scatter(X_plot[:, 0], X_plot[:, 1], c=cluster_membership, cmap='viridis', s=30)
plt.title('Fuzzy C-Means Clustering (2D Projection)')
plt.xlabel(features[0])
plt.ylabel(features[1])
plt.colorbar(label='Cluster')
plt.show()
